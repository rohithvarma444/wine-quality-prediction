# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from termcolor import colored 


from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, KFold
from sklearn.linear_model import LogisticRegression

# %%
pd.options.mode.copy_on_write = True 
sns.set_style('darkgrid')
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
sns.color_palette("cool_r", n_colors=1)
# Out:
# [(0.4980392156862745, 0.5019607843137255, 1.0)]

# %%
sns.set_palette("cool_r")
print(colored('\nAll libraries Configed succesfully.', 'green'))
# Out:
# All libraries Configed succesfully.

# %% [markdown]
# ## Start of the modelling

# %%
data = pd.read_csv("/home/r0h17h/ml-proj/wine-quality-prediction/datasets/winequality-red(1).csv")
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
data.describe().T.style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_c4774_row0_col0, #T_c4774_row1_col0, #T_c4774_row1_col7, #T_c4774_row2_col0, #T_c4774_row2_col3, #T_c4774_row2_col4, #T_c4774_row2_col7, #T_c4774_row3_col0, #T_c4774_row4_col0, #T_c4774_row4_col1, #T_c4774_row4_col2, #T_c4774_row4_col3, #T_c4774_row4_col4, #T_c4774_row4_col5, #T_c4774_row4_col6, #T_c4774_row4_col7, #T_c4774_row5_col0, #T_c4774_row6_col0, #T_c4774_row7_col0, #T_c4774_row7_col2, #T_c4774_row7_col7, #T_c4774_row8_col0, #T_c4774_row9_col0, #T_c4774_row10_col0, #T_c4774_row11_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c4774_row0_col1, #T_c4774_row10_col6 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_c4774_row0_col2, #T_c4774_row0_col7, #T_c4774_row3_col1, #T_c4774_row3_col5, #T_c4774_row3_col7, #T_c4774_row8_col6 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_c4774_row0_col3 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_c4774_row0_col4 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_c4774_row0_col5 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_c4774_row0_col6 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_c4774_row1_col1, #T_c4774_row1_col5, #T_c4774_row1_col6, #T_c4774_row9_col6 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_c4774_row1_col2, #T_c4774_row2_col1, #T_c4774_row2_col2, #T_c4774_row2_col5, #T_c4774_row2_col6, #T_c4774_row8_col2, #T_c4774_row9_col2, #T_c4774_row9_col7 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_c4774_row1_col3, #T_c4774_row1_col4, #T_c4774_row7_col6, #T_c4774_row8_col7, #T_c4774_row9_col1, #T_c4774_row9_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_c4774_row3_col2, #T_c4774_row3_col6, #T_c4774_row7_col4, #T_c4774_row9_col3 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_c4774_row3_col3 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_c4774_row3_col4, #T_c4774_row8_col5 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_c4774_row5_col1 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_c4774_row5_col2 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_c4774_row5_col3, #T_c4774_row7_col3, #T_c4774_row11_col1 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_c4774_row5_col4 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_c4774_row5_col5 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_c4774_row5_col6 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_c4774_row5_col7 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_c4774_row6_col1, #T_c4774_row6_col2, #T_c4774_row6_col4, #T_c4774_row6_col5, #T_c4774_row6_col6, #T_c4774_row6_col7, #T_c4774_row10_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c4774_row6_col3 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_c4774_row7_col1, #T_c4774_row9_col4 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_c4774_row7_col5, #T_c4774_row11_col2, #T_c4774_row11_col7 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_c4774_row8_col1 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_c4774_row8_col3 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_c4774_row8_col4 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_c4774_row10_col1, #T_c4774_row11_col4 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_c4774_row10_col2 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_c4774_row10_col4 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_c4774_row10_col5 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_c4774_row10_col7 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_c4774_row11_col3 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_c4774_row11_col5 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_c4774_row11_col6 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# </style>
# <table id="T_c4774">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4774_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_c4774_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_c4774_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_c4774_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_c4774_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_c4774_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_c4774_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_c4774_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4774_level0_row0" class="row_heading level0 row0" >fixed acidity</th>
#       <td id="T_c4774_row0_col0" class="data row0 col0" >1599.000000</td>
#       <td id="T_c4774_row0_col1" class="data row0 col1" >8.319637</td>
#       <td id="T_c4774_row0_col2" class="data row0 col2" >1.741096</td>
#       <td id="T_c4774_row0_col3" class="data row0 col3" >4.600000</td>
#       <td id="T_c4774_row0_col4" class="data row0 col4" >7.100000</td>
#       <td id="T_c4774_row0_col5" class="data row0 col5" >7.900000</td>
#       <td id="T_c4774_row0_col6" class="data row0 col6" >9.200000</td>
#       <td id="T_c4774_row0_col7" class="data row0 col7" >15.900000</td>
#     </tr>
#     <tr>
#       <th id="T_c4774_level0_row1" class="row_heading level0 row1" >volatile acidity</th>
#       <td id="T_c4774_row1_col0" class="data row1 col0" >1599.000000</td>
#       <td id="T_c4774_row1_col1" class="data row1 col1" >0.527821</td>
#       <td id="T_c4774_row1_col2" class="data row1 col2" >0.179060</td>
#       <td id="T_c4774_row1_col3" class="data row1 col3" >0.120000</td>
#       <td id="T_c4774_row1_col4" class="data row1 col4" >0.390000</td>
#       <td id="T_c4774_row1_col5" class="data row1 col5" >0.520000</td>
#       <td id="T_c4774_row1_col6" class="data row1 col6" >0.640000</td>
#       <td id="T_c4774_row1_col7" class="data row1 col7" >1.580000</td>
#     </tr>
#     <tr>
#       <th id="T_c4774_level0_row2" class="row_heading level0 row2" >citric acid</th>
#       <td id="T_c4774_row2_col0" class="data row2 col0" >1599.000000</td>
#       <td id="T_c4774_row2_col1" class="data row2 col1" >0.270976</td>
#       <td id="T_c4774_row2_col2" class="data row2 col2" >0.194801</td>
#       <td id="T_c4774_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_c4774_row2_col4" class="data row2 col4" >0.090000</td>
#       <td id="T_c4774_row2_col5" class="data row2 col5" >0.260000</td>
#       <td id="T_c4774_row2_col6" class="data row2 col6" >0.420000</td>
#       <td id="T_c4774_row2_col7" class="data row2 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c4774_level0_row3" class="row_heading level0 row3" >residual sugar</th>
#       <td id="T_c4774_row3_col0" class="data row3 col0" >1599.000000</td>
#       <td id="T_c4774_row3_col1" class="data row3 col1" >2.538806</td>
#       <td id="T_c4774_row3_col2" class="data row3 col2" >1.409928</td>
#       <td id="T_c4774_row3_col3" class="data row3 col3" >0.900000</td>
#       <td id="T_c4774_row3_col4" class="data row3 col4" >1.900000</td>
#       <td id="T_c4774_row3_col5" class="data row3 col5" >2.200000</td>
#       <td id="T_c4774_row3_col6" class="data row3 col6" >2.600000</td>
#       <td id="T_c4774_row3_col7" class="data row3 col7" >15.500000</td>
#     </tr>
#     <tr>
#       <th id="T_c4774_level0_row4" class="row_heading level0 row4" >chlorides</th>
#       <td id="T_c4774_row4_col0" class="data row4 col0" >1599.000000</td>
#       <td id="T_c4774_row4_col1" class="data row4 col1" >0.087467</td>
#       <td id="T_c4774_row4_col2" class="data row4 col2" >0.047065</td>
#       <td id="T_c4774_row4_col3" class="data row4 col3" >0.012000</td>
#       <td id="T_c4774_row4_col4" class="data row4 col4" >0.070000</td>
#       <td id="T_c4774_row4_col5" class="data row4 col5" >0.079000</td>
#       <td id="T_c4774_row4_col6" class="data row4 col6" >0.090000</td>
#       <td id="T_c4774_row4_col7" class="data row4 col7" >0.611000</td>
#     </tr>
#     <tr>
#       <th id="T_c4774_level0_row5" class="row_heading level0 row5" >free sulfur dioxide</th>
#       <td id="T_c4774_row5_col0" class="data row5 col0" >159

# %%
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.rename(columns = {"fixed acidity": "fixed_acidity",
                       "volatile acidity": "volatile_acidity",
                       "citric acid": "citric_acid",
                       "residual sugar": "residual_sugar",
                       "chlorides": "chlorides",
                       "free sulfur dioxide": "free_sulfur_dioxide",
                       "total sulfur dioxide": "total_sulfur_dioxide"},
            inplace = True)

# %%
columns = list(data.columns)

# %%
fig, ax = plt.subplots(11, 2, figsize=(15, 45))
plt.subplots_adjust(hspace = 0.5)
for i in range(11) :
    # AX 1
    sns.boxplot(x=columns[i], data=data, ax=ax[i, 0])
    # Ax 2
    sns.scatterplot(x=columns[i], y='quality', data=data, hue='quality', ax=ax[i, 1])

# %%
corr = data.corr()
# cmap = sns.diverging_palette(-1, 1, s=100, l=50, n=15, center="dark", as_cmap=True)
plt.figure(figsize=(9, 6))
sns.heatmap(corr, annot=True, fmt='.2f', linewidth=0.5, cmap='Purples', mask=np.triu(corr))
plt.show()

# %%
sns.pairplot(data, hue='quality', corner = True, palette='Purples')

# %%
data.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
data = data.replace({'quality' : {
                                    8 : 'Good',
                                    7 : 'Good',
                                    6 : 'Middle',
                                    5 : 'Middle',
                                    4 : 'Bad',
                                    3 : 'Bad',
        }}
)

# %%
data.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality
# 0      9.4  Middle
# 1      9.8  Middle
# 2      9.8  Middle
# 3      9.8  Middle
# 4      9.4  Middle

# %%
X_temp = data.drop(columns='quality')
y = data.quality

# %%
scaler = MinMaxScaler(feature_range=(0, 1)).fit_transform(X_temp)
X = pd.DataFrame(scaler, columns=X_temp.columns)
X.describe().T.style.background_gradient(axis=0, cmap='Purples')
# Out:
# <style type="text/css">
# #T_ed7e3_row0_col0, #T_ed7e3_row0_col3, #T_ed7e3_row1_col0, #T_ed7e3_row1_col3, #T_ed7e3_row1_col7, #T_ed7e3_row2_col0, #T_ed7e3_row2_col3, #T_ed7e3_row3_col0, #T_ed7e3_row3_col1, #T_ed7e3_row3_col3, #T_ed7e3_row3_col5, #T_ed7e3_row3_col6, #T_ed7e3_row4_col0, #T_ed7e3_row4_col2, #T_ed7e3_row4_col3, #T_ed7e3_row4_col7, #T_ed7e3_row5_col0, #T_ed7e3_row5_col3, #T_ed7e3_row6_col0, #T_ed7e3_row6_col3, #T_ed7e3_row6_col4, #T_ed7e3_row6_col7, #T_ed7e3_row7_col0, #T_ed7e3_row7_col3, #T_ed7e3_row8_col0, #T_ed7e3_row8_col3, #T_ed7e3_row9_col0, #T_ed7e3_row9_col3, #T_ed7e3_row10_col0, #T_ed7e3_row10_col3 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_ed7e3_row0_col1 {
#   background-color: #8d89c0;
#   color: #f1f1f1;
# }
# #T_ed7e3_row0_col2 {
#   background-color: #7b74b5;
#   color: #f1f1f1;
# }
# #T_ed7e3_row0_col4 {
#   background-color: #a5a2cd;
#   color: #f1f1f1;
# }
# #T_ed7e3_row0_col5 {
#   background-color: #9d99c7;
#   color: #f1f1f1;
# }
# #T_ed7e3_row0_col6 {
#   background-color: #7d77b7;
#   color: #f1f1f1;
# }
# #T_ed7e3_row0_col7, #T_ed7e3_row2_col7, #T_ed7e3_row3_col7, #T_ed7e3_row5_col7, #T_ed7e3_row7_col7, #T_ed7e3_row8_col7, #T_ed7e3_row9_col7 {
#   background-color: #c6c7e1;
#   color: #000000;
# }
# #T_ed7e3_row1_col1 {
#   background-color: #acaad1;
#   color: #000000;
# }
# #T_ed7e3_row1_col2 {
#   background-color: #bbbbdb;
#   color: #000000;
# }
# #T_ed7e3_row1_col4, #T_ed7e3_row8_col2 {
#   background-color: #bebedd;
#   color: #000000;
# }
# #T_ed7e3_row1_col5 {
#   background-color: #a8a6cf;
#   color: #f1f1f1;
# }
# #T_ed7e3_row1_col6 {
#   background-color: #9793c5;
#   color: #f1f1f1;
# }
# #T_ed7e3_row2_col1 {
#   background-color: #b1b1d5;
#   color: #000000;
# }
# #T_ed7e3_row2_col2, #T_ed7e3_row7_col1, #T_ed7e3_row7_col4, #T_ed7e3_row7_col5, #T_ed7e3_row7_col6, #T_ed7e3_row10_col7 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_ed7e3_row2_col4 {
#   background-color: #f2f0f7;
#   color: #000000;
# }
# #T_ed7e3_row2_col5 {
#   background-color: #afaed4;
#   color: #000000;
# }
# #T_ed7e3_row2_col6 {
#   background-color: #786db2;
#   color: #f1f1f1;
# }
# #T_ed7e3_row3_col2 {
#   background-color: #eae9f3;
#   color: #000000;
# }
# #T_ed7e3_row3_col4 {
#   background-color: #f9f7fb;
#   color: #000000;
# }
# #T_ed7e3_row4_col1 {
#   background-color: #f8f7fb;
#   color: #000000;
# }
# #T_ed7e3_row4_col4 {
#   background-color: #f0eef6;
#   color: #000000;
# }
# #T_ed7e3_row4_col5 {
#   background-color: #f6f5f9;
#   color: #000000;
# }
# #T_ed7e3_row4_col6 {
#   background-color: #f9f8fb;
#   color: #000000;
# }
# #T_ed7e3_row5_col1 {
#   background-color: #d9d9ea;
#   color: #000000;
# }
# #T_ed7e3_row5_col2 {
#   background-color: #8885be;
#   color: #f1f1f1;
# }
# #T_ed7e3_row5_col4, #T_ed7e3_row6_col1 {
#   background-color: #f4f2f8;
#   color: #000000;
# }
# #T_ed7e3_row5_col5 {
#   background-color: #ddddec;
#   color: #000000;
# }
# #T_ed7e3_row5_col6 {
#   background-color: #bebfdd;
#   color: #000000;
# }
# #T_ed7e3_row6_col2, #T_ed7e3_row10_col4 {
#   background-color: #c9c9e2;
#   color: #000000;
# }
# #T_ed7e3_row6_col5 {
#   background-color: #f6f4f9;
#   color: #000000;
# }
# #T_ed7e3_row6_col6 {
#   background-color: #e6e5f1;
#   color: #000000;
# }
# #T_ed7e3_row7_col2 {
#   background-color: #9a96c6;
#   color: #f1f1f1;
# }
# #T_ed7e3_row8_col1 {
#   background-color: #51218c;
#   color: #f1f1f1;
# }
# #T_ed7e3_row8_col4, #T_ed7e3_row8_col5 {
#   background-color: #50208c;
#   color: #f1f1f1;
# }
# #T_ed7e3_row8_col6 {
#   background-color: #51228d;
#   color: #f1f1f1;
# }
# #T_ed7e3_row9_col1 {
#   background-color: #dedeed;
#   color: #000000;
# }
# #T_ed7e3_row9_col2 {
#   background-color: #e3e2ef;
#   color: #000000;
# }
# #T_ed7e3_row9_col4 {
#   background-color: #e0dfee;
#   color: #000000;
# }
# #T_ed7e3_row9_col5 {
#   background-color: #e1e0ee;
#   color: #000000;
# }
# #T_ed7e3_row9_col6 {
#   background-color: #d5d5e9;
#   color: #000000;
# }
# #T_ed7e3_row10_col1 {
#   background-color: #9894c5;
#   color: #f1f1f1;
# }
# #T_ed7e3_row10_col2 {
#   background-color: #6c55a5;
#   color: #f1f1f1;
# }
# #T_ed7e3_row10_col5 {
#   background-color: #a6a3cd;
#   color: #f1f1f1;
# }
# #T_ed7e3_row10_col6 {
#   background-color: #7a71b4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ed7e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed7e3_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_ed7e3_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_ed7e3_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_ed7e3_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_ed7e3_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_ed7e3_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_ed7e3_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_ed7e3_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed7e3_level0_row0" class="row_heading level0 row0" >fixed_acidity</th>
#       <td id="T_ed7e3_row0_col0" class="data row0 col0" >1599.000000</td>
#       <td id="T_ed7e3_row0_col1" class="data row0 col1" >0.329171</td>
#       <td id="T_ed7e3_row0_col2" class="data row0 col2" >0.154079</td>
#       <td id="T_ed7e3_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_ed7e3_row0_col4" class="data row0 col4" >0.221239</td>
#       <td id="T_ed7e3_row0_col5" class="data row0 col5" >0.292035</td>
#       <td id="T_ed7e3_row0_col6" class="data row0 col6" >0.407080</td>
#       <td id="T_ed7e3_row0_col7" class="data row0 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ed7e3_level0_row1" class="row_heading level0 row1" >volatile_acidity</th>
#       <td id="T_ed7e3_row1_col0" class="data row1 col0" >1599.000000</td>
#       <td id="T_ed7e3_row1_col1" class="data row1 col1" >0.279329</td>
#       <td id="T_ed7e3_row1_col2" class="data row1 col2" >0.122644</td>
#       <td id="T_ed7e3_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_ed7e3_row1_col4" class="data row1 col4" >0.184932</td>
#       <td id="T_ed7e3_row1_col5" class="data row1 col5" >0.273973</td>
#       <td id="T_ed7e3_row1_col6" class="data row1 col6" >0.356164</td>
#       <td id="T_ed7e3_row1_col7" class="data row1 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ed7e3_level0_row2" class="row_heading level0 row2" >citric_acid</th>
#       <td id="T_ed7e3_row2_col0" class="data row2 col0" >1599.000000</td>
#       <td id="T_ed7e3_row2_col1" class="data row2 col1" >0.270976</td>
#       <td id="T_ed7e3_row2_col2" class="data row2 col2" >0.194801</td>
#       <td id="T_ed7e3_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_ed7e3_row2_col4" class="data row2 col4" >0.090000</td>
#       <td id="T_ed7e3_row2_col5" class="data row2 col5" >0.260000</td>
#       <td id="T_ed7e3_row2_col6" class="data row2 col6" >0.420000</td>
#       <td id="T_ed7e3_row2_col7" class="data row2 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ed7e3_level0_row3" class="row_heading level0 row3" >residual_sugar</th>
#       <td id="T_ed7e3_row3_col0" class="data row3 col0" >1599.000000</td>
#       <td id="T_ed7e3_row3_col1" class="data row3 col1" >0.112247</td>
#       <td id="T_ed7e3_row3_col2" class="data row3 col2" >0.096570</td>
#       <td id="T_ed7e3_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_ed7e3_row3_col4" class="data row3 col4" >0.068493</td>
#       <td id="T_ed7e3_row3_col5" class="data row3 col5" >0.089041</td>
#       <td id="T_ed7e3_row3_col6" class="data row3 col6" >0.116438</td>
#       <td id="T_ed7e3_row3_col7" class="data row3 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ed7e3_level0_row4" class="row_heading level0 row4" >chlorides</th>
#       <td id="T_ed7e3_row4_col0" class="data row4 col0" >1599.000000</td>
#       <td id="T_ed7e3_row4_col1" class="data row4 col1" >0.125988</td>
#       <td id="T_ed7e3_row4_col2" class="data row4 col2" >0.078573</td>
#       <td id="T_ed7e3_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_ed7e3_row4_col4" class="data row4 col4" >0.096828</td>
#       <td id="T_ed7e3_row4_col5" class="data row4 col5" >0.111853</td>
#       <td id="T_ed7e3_row4_col6" c

# %% [markdown]
# # Modelling

# %%
def plot_confusion_matrix(y_test, y_prediction):
    '''Plotting Confusion Matrix'''
    cm = metrics.confusion_matrix(y_test, y_prediction)
    ax = plt.subplot()
    ax = sns.heatmap(cm, annot=True, fmt='', cmap="Purples")
    ax.set_xlabel('Prediced labels', fontsize=18)
    ax.set_ylabel('True labels', fontsize=18)
    ax.set_title('Confusion Matrix', fontsize=25)
    ax.xaxis.set_ticklabels(['Bad', 'Good', 'Middle'])
    ax.yaxis.set_ticklabels(['Bad', 'Good', 'Middle']) 
    plt.show()

# %%
def clfr_plot(y_test, y_pred) :
    ''' Plotting Classification report'''
    cr = pd.DataFrame(metrics.classification_report(y_test, y_pred_rf, digits=3,
                                            output_dict=True)).T
    cr.drop(columns='support', inplace=True)
    sns.heatmap(cr, cmap='Purples', annot=True, linecolor='white', linewidths=0.5).xaxis.tick_top()

# %%
def clf_plot(y_pred) :
    '''
    1) Ploting Confusion Matrix
    2) Plotting Classification Report'''
    cm = metrics.confusion_matrix(y_test, y_pred)
    cr = pd.DataFrame(metrics.classification_report(y_test, y_pred, digits=3, output_dict=True)).T
    cr.drop(columns='support', inplace=True)
    
    fig, ax = plt.subplots(1, 2, figsize=(15, 5))
    
    ax[0] = sns.heatmap(cm, annot=True, fmt='', cmap="Purples", ax=ax[0])
    ax[0].set_xlabel('Prediced labels', fontsize=18)
    ax[0].set_ylabel('True labels', fontsize=18)
    ax[0].set_title('Confusion Matrix', fontsize=25)
    ax[0].xaxis.set_ticklabels(['Bad', 'Good', 'Middle'])
    ax[0].yaxis.set_ticklabels(['Bad', 'Good', 'Middle'])
    
    ax[1] = sns.heatmap(cr, cmap='Purples', annot=True, linecolor='white', linewidths=0.5, ax=ax[1])
    ax[1].xaxis.tick_top()
    ax[1].set_title('Classification Report', fontsize=25)
    plt.show()

# %%
data.quality.value_counts()
# Out:
# quality
# Middle    1319
# Good       217
# Bad         63
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %% [markdown]
# # Logistic Regression

# %%
parameters = {
    'C' : [0.001, 0.01, 0.1, 1.0, 10, 100, 1000],
    'class_weight' : ['balanced'],
    'solver' : ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga']
}

lr = LogisticRegression()
lr_cv = GridSearchCV(estimator=lr, param_grid=parameters, cv=10).fit(X_train, y_train)

print('Tuned hyper parameters : ', lr_cv.best_params_)
print('accuracy : ', lr_cv.best_score_)
# Out:
# Tuned hyper parameters :  {'C': 0.1, 'class_weight': 'balanced', 'solver': 'liblinear'}
# accuracy :  0.82484593837535

# %%
lr = LogisticRegression(**lr_cv.best_params_).fit(X_train, y_train)

# %%
y_pred_lr = lr.predict(X_test)

lr_score = round(lr.score(X_test, y_test), 3)
print('LogisticRegression score : ', lr_score)
# Out:
# LogisticRegression score :  0.85

# %%
clf_plot(y_pred_lr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 clf_plot(y_pred_lr)
#
# Cell In[26], line 5, in clf_plot(y_pred)
#       1 def clf_plot(y_pred) :
#       2     '''
#       3     1) Ploting Confusion Matrix
#       4     2) Plotting Classification Report'''
# ----> 5     cm = metrics.confusion_matrix(y_test, y_pred)
#       6     cr = pd.DataFrame(metrics.classification_report(y_test, y_pred, digits=3, output_dict=True)).T
#       7     cr.drop(columns='support', inplace=True)
#
# NameError: name 'metrics' is not defined
